# %%
import pandas as pd

# Example: Analyze NotebookLM flashcards
flashcards = {
    "Q1": "How many years of ITS experience?",
    "A1": "14+ years",
    "Q2": "Key areas of expertise?",
    "A2": "Tolling, Traffic Management, Smart Mobility, AI in Transport"
}

df = pd.DataFrame(list(flashcards.items()), columns=["Question", "Answer"])
print(df)
# Out:
#   Question                                             Answer
# 0       Q1                  How many years of ITS experience?
# 1       A1                                          14+ years
# 2       Q2                            Key areas of expertise?
# 3       A2  Tolling, Traffic Management, Smart Mobility, A...

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Example Mindmap
edges = [
    ("ITS", "Traffic Management"),
    ("ITS", "Tolling"),
    ("ITS", "EV Integration"),
    ("ITS", "AI in Transport")
]

G = nx.Graph()
G.add_edges_from(edges)

plt.figure(figsize=(6,6))
nx.draw(G, with_labels=True, node_color="lightblue", font_size=10, node_size=3000)
plt.show()

# %%
import random

questions = [
    "What is MLFF in Tolling?",
    "How can AI improve traffic management?",
    "Name one predictive maintenance use-case in ITS.",
    "What role does Power BI play in ITS dashboards?"
]

print("### Random Quiz ###")
for q in random.sample(questions, 3):
    print(f"- {q}")
# Out:
# ### Random Quiz ###
# - Name one predictive maintenance use-case in ITS.
# - What role does Power BI play in ITS dashboards?
# - What is MLFF in Tolling?
